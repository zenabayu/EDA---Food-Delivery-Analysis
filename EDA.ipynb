# %% [markdown]
# <a href="https://colab.research.google.com/github/zenabayu/EDA---Food-Delivery-Analysis/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generic Analysis
#
# *   Bagaimana bentuk dari data yang kita miliki?
#       Berapa jumlah baris dan kolom
# *   Tipe data yang kita miliki
# *   Periksa kolom target dan feature
# *   Apakah ada duplicate value?
# *   Apakah ada missing value
#
# # Focus to Target
#
#
# *   Bagaimana statistics nilai target?
# *   Apakah ada feature yang berkorelasi dengan nilai target?
#
#
#
#
#
#
# ---

# %% [markdown]
# #EDA - Food Delivery Analysis

# %% [markdown]
# ## Import Library dan Data

# %%
import pandas as pd
df = pd.read_csv('Food_Delivery_Dataset.csv')

# %% [markdown]
# ##Bagaimana bentuk dari data yang kita miliki?

# %%
# (baris, kolom)
df.shape
# Out:
# (12773, 20)

# %%
# Bentuk datanya 45 rb baris dan 20 kolom
# Satu baris artinya satu pesanan
# Kolom target adalah 'time_taken_min'
df.head(5)
# Out:
#        id delivery_person_id  delivery_person_age  delivery_person_ratings  \
# 0  0x6b1a      JAPRES05DEL01                 28.0                      4.9
# 1   0xb46     PUNERES20DEL02                 34.0                      3.5
# 2  0x6adc     BANGRES19DEL02                 34.0                      4.9
# 3  0x4477    COIMBRES12DEL03                 37.0                      4.8
# 4  0x48ee      JAPRES19DEL01                 38.0                      4.7
#
#    restaurant_latitude  restaurant_longitude  delivery_location_latitude  \
# 0            26.905287             75.794592                   26.915287
# 1            18.592718             73.773572                   18.672718
# 2            12.914264             77.678400                   12.964264
# 3            11.000762             76.981876                   11.060762
# 4            26.913726             75.752820                   26.953726
#
#    delivery_location_longitude  order_date time_orderd time_order_picked  \
# ...

# %%
## Tipe data yang kita miliki

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12773 entries, 0 to 12772
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           12773 non-null  object
#  1   delivery_person_id           12773 non-null  object
#  2   delivery_person_age          12278 non-null  float64
#  3   delivery_person_ratings      12262 non-null  float64
#  4   restaurant_latitude          12772 non-null  float64
#  5   restaurant_longitude         12772 non-null  float64
#  6   delivery_location_latitude   12772 non-null  float64
#  7   delivery_location_longitude  12772 non-null  float64
#  8   order_date                   12772 non-null  object
#  9   time_orderd                  12318 non-null  object
#  10  time_order_picked            12772 non-null  object
#  11  weather_conditions           12609 non-null  object
# ...

# %% [markdown]
# 1. 8 Variabel desimal
# 2. 1 Variabel integer
# 3. 11 Variabel kategori
# 4. Variabel target (time_taken_min) berbentuk desimal

# %% [markdown]
# ## Periksa kolom target dan feature
#
# 1. Kolom targer adalah 'time_taken_min'
# 2. Kolom feature adalah sisanya, kecuali: kolom id

# %% [markdown]
# ### Apakah ada duplicate value?

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Tidak ada duplicate value

# %% [markdown]
# ### Apakah ada missing value?

# %%
df.isnull().sum()
# Out:
# id                               0
# delivery_person_id               0
# delivery_person_age            495
# delivery_person_ratings        511
# restaurant_latitude              1
# restaurant_longitude             1
# delivery_location_latitude       1
# delivery_location_longitude      1
# order_date                       1
# time_orderd                    455
# time_order_picked                1
# weather_conditions             164
# road_traffic_density           158
# vehicle_condition                1
# type_of_order                    1
# type_of_vehicle                  1
# multiple_deliveries            277
# festival                        74
# city                           337
# time_taken_min                   1
# dtype: int64

# %% [markdown]
# Ada 8 kolom yang memiliki missing value

# %% [markdown]
# # Focus to Target

# %% [markdown]
# Univarate Analysis: Target

# %%
df['time_taken_min'].describe()
# Out:
# count    12772.000000
# mean        26.316395
# std          9.483483
# min         10.000000
# 25%         19.000000
# 50%         25.000000
# 75%         32.000000
# max         54.000000
# Name: time_taken_min, dtype: float64

# %%
df['time_taken_min'].hist()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

plt.boxplot(df['time_taken_min'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78246fdd9750>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x78246fdd9c90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x78246fdd94b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x78246fdda1d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78246fdda470>],
#  'means': []}

# %% [markdown]
# ## Multivariate Analisys: Focus to Target

# %%
import seaborn as sns
sns.heatmap(round(df.select_dtypes('number').corr(),2),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Variabel yang berkorelasi adalah :
#
#
# 1.   Multiple_deliveries
# 2.   Rating
# 3.   Age
# 4.   Vehicle_condotion

# %%
cols = ['multiple_deliveries','delivery_person_age','vehicle_condition','time_taken_min']

# %%
sns.pairplot(df[cols],diag_kind='kde')
